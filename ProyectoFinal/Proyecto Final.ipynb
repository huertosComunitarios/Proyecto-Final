# %% [markdown]
# ### Se necesita tener andando el servicio de la app, ejecutar el codigo y luego desde del navegador entrar a http://127.0.0.1:5000/ , de lo contrario las paginas no cargaran correctamente

# %%
'http://127.0.0.1:5000/'
# Out:
# 'http://127.0.0.1:5000/'

# %%
index = '''

<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <meta name="viewport" contet="widht=device-width">
        <title> Tarea Autonoma Flask</title>
        <link rel="stylesheet" href="static/css/style.css">
        <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
        <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script>
        <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js"></script>
        <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>
    </head>
    <body>
         <!------------------------------------------>
        <header>
            <div class="container">
                <div id="branding">
                    <nav>
                        <ul>
                            <li class="current"><a href="http://127.0.0.1:5000/index">home</a></li>
                            <li><a href="http://127.0.0.1:5000/acercaDe">Acerca De</a></li>
                            <li><a href="http://127.0.0.1:5000/galeria">Galeria</a></li>
                            <li><a href="http://127.0.0.1:5000/mapa">Mapa</a></li>
                        </ul>
                    </nav>
                </div>
            </div>
        </header>
 <!------------------------------------------>
        <section id="showcase">
            <div id="demo" class="carousel slide" data-ride="carousel">
              <ul class="carousel-indicators">
                <li data-target="#demo" data-slide-to="0" class="active"></li>
                <li data-target="#demo" data-slide-to="1"></li>
                <li data-target="#demo" data-slide-to="2"></li>
                <li data-target="#demo" data-slide-to="3"></li>
              </ul>
              <div class="carousel-inner">
                <div class="carousel-item active">
                  <img src="static/photos/1.png"  width="1100" height="550">
                  <div class="carousel-caption">
                    <p>Cerros de Valparaiso</p>
                  </div>   
                </div>
                <div class="carousel-item">
                  <img src="static/photos/2.png"  width="1100" height="550">
                  <div class="carousel-caption">
                    <p>Cerros de Valparaiso</p>
                  </div>   
                </div>
                <div class="carousel-item">
                  <img src="static/photos/6.png"  width="1100" height="550">
                  <div class="carousel-caption">
                    <p>Cerros de Valparaiso</p>
                  </div>   
                </div>
                <div class="carousel-item">
                  <img src="static/photos/12.png"  width="1100" height="550">
                  <div class="carousel-caption">
                    <p>Cerros de Valparaiso</p>
                  </div>   
                </div>
              </div>
              <a class="carousel-control-prev" href="#demo" data-slide="prev">
                <span class="carousel-control-prev-icon"></span>
              </a>
              <a class="carousel-control-next" href="#demo" data-slide="next">
                <span class="carousel-control-next-icon"></span>
              </a>
            </div>
        </section>
<!------------------------------------------>
<section >

<div class="row" >
  <div class="col-md-auto">

    <div class="card" style="width: 18rem;">
    <img class="card-img-top" src="https://www.portalagrochile.cl/wp-content/uploads/2021/08/revista-especializada-del-cerezo-lanza-su-segunda-edicion-533x261.jpg" alt="Card image cap">
      <div class="card-body">
      <h5 class="card-title">Revista especializada del Cerezo, lanza su segunda edición</h5>
      <p class="card-text">Revista del cerezo. Luego de un exitoso debut en diciembre del 2020, PEC Chile lanzó este 15 de Agosto la segunda edición de PEC Magazine. "Queremos... </p>
      <a href="https://www.portalagrochile.cl/2021/08/16/revista-especializada-del-cerezo-lanza-su-segunda-edicion/" class="btn btn-primary">Mas informacion</a>
       </div>
    </div>
  </div>

  <div class="col-md-auto">
    <div class="card" style="width: 18rem;">
      <img class="card-img-top" src="https://www.portalagrochile.cl/wp-content/uploads/2021/08/Expo-Chile-Agricola-2021-324x160.jpg" alt="Card image cap">
      <div class="card-body">
       <h5 class="card-title">Riego con nanoburbujas o con vasijas ancestrales son algunos atractivos de...</h5>
        <p class="card-text">Ahorrar hasta 80 porciento de agua en riego mediante el resurgimiento de una práctica ancestral basada en el uso de vasijas de greda o experimentar... </p>
        <a href="https://www.portalagrochile.cl/2021/08/14/riego-con-nanoburbujas-o-con-vasijas-ancestrales-son-algunos-atractivos-de-expo-chile-agricola-2021/" class="btn btn-primary">Mas informacion</a>
     </div>
    </div>
  </div>

  <div class="col-md-auto">
    <div class="card" style="width: 18rem;">
     <img class="card-img-top" src="https://www.portalagrochile.cl/wp-content/uploads/2021/08/construccion-y-rehabilitacion-de-pozos-533x261.jpg" alt="Card image cap">
     <div class="card-body">
        <h5 class="card-title">Hasta el 19 de agosto regantes de todo el país podrán...</h5>
        <p class="card-text">Ahorrar hasta 80 porciento de agua en riego mediante el resurgimiento de una práctica ancestral basada en el uso de vasijas de greda o experimentar..</p>
        <a href="https://www.portalagrochile.cl/2021/08/14/hasta-el-19-de-agosto-regantes-de-todo-el-pais-podran-presentar-sus-iniciativas-a-concurso-destinado-a-construccion-y-rehabilitacion-de-pozos/" class="btn btn-primary">Mas informacon</a>
      </div>
    </div>
  </div>
</div>

<div class="row">
  <div class="col-md-auto">

    <div class="card" style="width: 18rem;">
      <img class="card-img-top" src="" alt="Card image cap">
      <div class="card-body">
       <h5 class="card-title">Noticia</h5>
       <p class="card-text">Lorem Ipsun is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industr ys standard dummy text ever since the 1500 when an unknown printer took a galley of type and scrambled it to make a type specimen book</p>
       <a href=" " class="btn btn-primary">Mas informacion</a>
      </div>
    </div>
  </div>

  <div class="col-md-auto">
  <div class="card" style="width: 18rem;">
    <img class="card-img-top" src="" alt="Card image cap">
    <div class="card-body">
      <h5 class="card-title">Noticia</h5>
      <p class="card-text">Lorem Ipsun is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industr ys standard dummy text ever since the 1500 when an unknown printer took a galley of type and scrambled it to make a type specimen book</p>
      <a href=" " class="btn btn-primary">Mas informacion</a>
    </div>
  </div>
</div>

<div class="col-md-auto">
  <div class="card" style="width: 18rem;">
   <img class="card-img-top" src="" alt="Card image cap">
    <div class="card-body">
     <h5 class="card-title">Noticia</h5>
     <p class="card-text">Lorem Ipsun is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industr ys standard dummy text ever since the 1500 when an unknown printer took a galley of type and scrambled it to make a type specimen book</p>
     <a href=" " class="btn btn-primary">Mas informacion</a>
   </div>
  </div>
</div>
</div>

<div class="row">  
    <div class="col-md-auto">

   <div class="card" style="width: 18rem;">
    <img class="card-img-top" src="" alt="Card image cap">
        <div class="card-body">
         <h5 class="card-title">Noticia</h5>
          <p class="card-text">Lorem Ipsun is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industr ys standard dummy text ever since the 1500 when an unknown printer took a galley of type and scrambled it to make a type specimen book</p>
         <a href="" class="btn btn-primary">Mas informacion</a>
        </div>
  </div>
</div>

<div class="col-md-auto">
        <div class="card" style="width: 18rem;">
          <img class="card-img-top" src="" alt="Card image cap">
          <div class="card-body">
            <h5 class="card-title">Noticia</h5>
            <p class="card-text">Lorem Ipsun is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industr ys standard dummy text ever since the 1500 when an unknown printer took a galley of type and scrambled it to make a type specimen book</p>
            <a href="" class="btn btn-primary">Mas informacion</a>
          </div>
        </div>
      </div>

      <div class="col-md-auto">
        <div class="card" style="width: 18rem;">
        <img class="card-img-top" src="" alt="Card image cap">
          <div class="card-body">
          <h5 class="card-title">Noticia</h5>
          <p class="card-text">Lorem Ipsun is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industr ys standard dummy text ever since the 1500 when an unknown printer took a galley of type and scrambled it to make a type specimen book</p>
          <a href="" class="btn btn-primary">Mas informacion</a>
          </div>
      </div>
    </div>
  </div>
</div>

  </section>
<!------------------------------------------>
<footer>
    <section class="mb-1" style="display: inline-flex; " >
      <!-- Facebook -->

      <!-- Twitter -->
      <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
        <img class="card-img" src="static/photos/upla1.png" alt="Card image cap">

        </div>
      
        <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px;">
          <img class="card-img" src="static/photos/vinculate1.png" alt="Card image cap">

          </div>
      
          <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
            <img class="card-img" src="static/photos/moneda.png" alt="Card image cap">

            </div>

            <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
              <img class="card-img" src="static/photos/valpo.png" alt="Card image cap">

              </div>
            
    </section>
    
    <!-- Section: Social media -->
  <!-- Grid container -->


</footer>

<div style="background-color: #5D4037; color: #ffffff"><center> 2021 Proyecto Final</center></div>

    </body>
</html>


'''
file = open('templates/index.html','w', encoding ='utf-8')
file.write(index)
file.close()

# %%
acercaDe ='''

<!DOCTYPE html>
<html>
    <head>
        <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
        <meta name="viewport" contet="widht=device-width">
        <title> Tarea Autonoma Flask</title>
        <link rel="stylesheet" href="static/css/style.css">
        <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
    </head>



         <body>
            <header>
                <div class="container">
                    <div id="branding">
                        <nav>
                            <ul>
                                <li ><a href="http://127.0.0.1:5000/index">Home</a></li>
                                <li class="current"><a href="http://127.0.0.1:5000/acercaDe">Acerca De</a></li>
                                <li ><a href="http://127.0.0.1:5000/galeria">Galeria</a></li>
                                <li ><a href="http://127.0.0.1:5000/mapa">Mapa</a></li>
                            </ul>
                        </nav>
                    </div>
                </div>
            </header>

<div class="contenedor ">
<section id="main">
    <div class="container">
      <article id="main-col">
        <h3 class="page-title">Acerca de nosotros</h3>
        <p>
           Los Huertos comunitarios estan destinados para el cultivo de plantas horticolas (ajo, cebollas, zanahorias, acelgas, entre otros). Estas plantas tienen como base la agricultura ecologica y se pueden potenciar con tecnologia. Ademas, cabe destacar que no solo proveera alimentos sanos y frescos, sino que tambien permite que se trabaje con los residuos organicos de los mismos miembros de la comunidad, genera pertenencia con el lugar, sirve como terapia y es el primer paso para una mayor independencia alimentaria, ya que muchos de estos huertos son la base de los comedores sociales de Valparaiso.
           Es por eso que nuestro objetivo es potenciar, a traves de la informatica, la agricultura para entregar un mayor control de cada uno de los huertos. El proyecto se enmarca en el area del Internet de las Cosas IoT vinculado a la Informatica Agricola.

    </article><br><br><br>
 <img src="static/photos/equipo.png" class="img-fluid" > 
  

    </div>
    <div class="ratio ratio-16x9"><center>
            <iframe width="460" height="315" src="https://www.youtube.com/embed/udvInRqDshI" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe> </center></div>
  </section>

</div>
<!------------------------------------------>
<footer>
    <section class="mb-1" style="display: inline-flex; " >
      <!-- Facebook -->

      <!-- Twitter -->
      <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
        <img class="card-img" src="static/photos/upla1.png" alt="Card image cap">

        </div>
      
        <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px;">
          <img class="card-img" src="static/photos/vinculate1.png" alt="Card image cap">

          </div>
      
          <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
            <img class="card-img" src="static/photos/moneda.png" alt="Card image cap">

            </div>

            <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
              <img class="card-img" src="static/photos/valpo.png" alt="Card image cap">

              </div>
            
    </section>
    
    <!-- Section: Social media -->
  <!-- Grid container -->


</footer>

<div style="background-color: #5D4037; color: #ffffff"><center> 2021 Proyecto Final</center></div>

    </body>
</html>
'''
file = open('templates/acercaDe.html','w' , encoding ='utf-8')
file.write(acercaDe)
file.close()

# %%
galeria ='''

<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <meta name="viewport" contet="widht=device-width">
        <title> Tarea Autonoma Flask</title>
        <link rel="stylesheet" href="static/css/style.css">
        <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
    </head>
     <!------------------------------------------>
    <body>
         <!------------------------------------------>
         <header>
            <div class="container">
                <div id="branding">
                    <nav>
                        <ul>
                            <li ><a href="http://127.0.0.1:5000/index">home</a></li>
                            <li ><a href="http://127.0.0.1:5000/acercaDe">Acerca De</a></li>
                            <li class="current" ><a href="http://127.0.0.1:5000/galeria">Galeria</a></li>
                            <li ><a href="http://127.0.0.1:5000/mapa">Mapa</a></li>
                        </ul>
                    </nav>
                </div>
            </div>
        </header>

<section id="main">
    <div class="container">
<!-- Gallery -->
<div class="row">
  <div class="col-lg-4 col-md-12 mb-4 mb-lg-0">
    <img
      src="static/photos/1.png"
      class="w-100 shadow-1-strong rounded mb-4"
      alt="Chincol"
    />

    <img
      src="static/photos/2.png"
      class="w-100 shadow-1-strong rounded mb-4"
      alt=""
    />
  </div>

  <div class="col-lg-4 mb-4 mb-lg-0">
    <img
      src="static/photos/3.jpg"
      class="w-100 shadow-1-strong rounded mb-4"
      alt=""
    />

    <img
      src="static/photos/4.png"
      class="w-100 shadow-1-strong rounded mb-4"
      alt=""
    />
  </div>

  <div class="col-lg-4 mb-4 mb-lg-0">
    <img
      src="static/photos/5.png"
      class="w-100 shadow-1-strong rounded mb-4"
      alt=""
    />

    <img
      src="static/photos/6.png"
      class="w-100 shadow-1-strong rounded mb-4"
      alt=""
    />
  </div>

  <div class="col-lg-4 mb-4 mb-lg-0">
    <img
      src="static/photos/7.png"
      class="w-100 shadow-1-strong rounded mb-4"
      alt=""
    />

    <img
      src="static/photos/8.png"
      class="w-100 shadow-1-strong rounded mb-4"
      alt=""
    />
  </div>

  <div class="col-lg-4 mb-4 mb-lg-0">
    <img
      src="static/photos/9.png"
      class="w-100 shadow-1-strong rounded mb-4"
      alt=""
    />

    <img
      src="static/photos/10.png"
      class="w-100 shadow-1-strong rounded mb-4"
      alt=""
    />
  </div>

  <div class="col-lg-4 mb-4 mb-lg-0">
    <img
      src="static/photos/11.png"
      class="w-100 shadow-1-strong rounded mb-4"
      alt=""
    />

    <img
      src="static/photos/12.png"
      class="w-100 shadow-1-strong rounded mb-4"
      alt=""
    />
  </div>

</div>
<!-- Gallery -->

    </div>
  </section>
<!------------------------------------------>
<footer>
    <section class="mb-1" style="display: inline-flex; " >
      <!-- Facebook -->

      <!-- Twitter -->
      <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
        <img class="card-img" src="static/photos/upla1.png" alt="Card image cap">

        </div>
      
        <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px;">
          <img class="card-img" src="static/photos/vinculate1.png" alt="Card image cap">

          </div>
      
          <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
            <img class="card-img" src="static/photos/moneda.png" alt="Card image cap">

            </div>

            <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
              <img class="card-img" src="static/photos/valpo.png" alt="Card image cap">

              </div>
            
    </section>
    
    <!-- Section: Social media -->
  <!-- Grid container -->


</footer>

<div style="background-color: #5D4037; color: #ffffff"><center> 2021 Proyecto Final</center></div>


    </body>
</html>

'''
file = open('templates/galeria.html','w',  encoding ='utf-8')
file.write(galeria)
file.close()

# %%
mapa ='''



<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <meta name="viewport" contet="widht=device-width">
        <title>Proyeto finalk</title>
        <link rel="stylesheet" href="static/css/style.css">
        <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
    </head>
     <!------------------------------------------>
    <body>
         <!------------------------------------------>
         <header>
            <div class="container">
                <div id="branding">
                    <nav>
                        <ul>
                            <li ><a href="http://127.0.0.1:5000/index">home</a></li>
                            <li ><a href="http://127.0.0.1:5000/acercaDe">Acerca De</a></li>
                            <li ><a href="http://127.0.0.1:5000/galeria">Galeria</a></li>
                            <li class="current"><a href="http://127.0.0.1:5000/mapa">Mapa</a></li>
                        </ul>
                    </nav>
                </div>
            </div>
        </header>

<section id="main">
    <div class="container">
<!-- Gallery -->
<div class="row">
<iframe src="https://www.google.com/maps/d/u/0/embed?mid=1SW25uwAwPN9OBt51U6K74XgSxRvkMkOd" width="640" height="480"></iframe>

<div class="col-md-auto">
    <div class="dark"> 
        <h3>Contactanos</h3>
        <form class="contacto">
            <div>
                <label>Nombre y apellido</label>
                <input type="text" placeholder="Nombre y apellido">
            </div>
            <div>

                <label>Correo Electronico</label>
                <input type="text"  placeholder="Correo electronico">

            </div>
            <div>
                <label>El Mensaje</label>
                <hr>
                <textarea placeholder="Mensaje"></textarea>
            </div>
            <button class="button_1"type="submit">Enviar</button>
        </form>

    </div>

  </div>
</div>

<!-- Gallery -->

    </div>
  </section>
<!------------------------------------------>
<footer>
    <section class="mb-1" style="display: inline-flex; " >
      <!-- Facebook -->

      <!-- Twitter -->
      <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
        <img class="card-img" src="static/photos/upla1.png" alt="Card image cap">

        </div>
      
        <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px;">
          <img class="card-img" src="static/photos/vinculate1.png" alt="Card image cap">

          </div>
      
          <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
            <img class="card-img" src="static/photos/moneda.png" alt="Card image cap">

            </div>

            <div class="card p-3" style="width: 15rem; background-color: #ffffff; margin-right:5px; ">
              <img class="card-img" src="static/photos/valpo.png" alt="Card image cap">

              </div>
            
    </section>
    
    <!-- Section: Social media -->
  <!-- Grid container -->


</footer>

<div style="background-color: #5D4037; color: #ffffff"><center> 2021 Proyecto Final</center></div>
 </body>
</html>



'''
file = open('templates/mapa.html','w',  encoding ='utf-8')
file.write(mapa)
file.close()

# %%
from flask import Flask
from flask import render_template
from flask_ngrok import run_with_ngrok
 

app = Flask(__name__,template_folder='templates', static_folder='static')
run_with_ngrok(app)

@app.route('/')
def bienvenido():
    return '''              
    <center>
    <head>
        <meta charset="utf-8">
        <meta name="viewport" contet="widht=device-width">
        <title> Tarea Autonoma Flask</title>
        <link rel="stylesheet" href="static/css/style.css">
        <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
        <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script>
        <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js"></script>
        <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>
    </head>

    <div class="card" style="width: 18rem; margin-top: 10%;">
        <div>
          <li ><a href="http://127.0.0.1:5000/index">Inicio</a></li>
          <li ><a href="http://127.0.0.1:5000/acercaDe">Acerca de</a></li>
          <li ><a href="http://127.0.0.1:5000/galeria">Galeria</a></li>
          <li ><a href="http://127.0.0.1:5000/mapa">Mapa</a></li>
          <img src="https://i.pinimg.com/originals/07/75/72/077572680c28d428423b83a9bec436b7.gif" width="250" />
        </div>


<div style="background-color: #5D4037; color: #ffffff"><center> © 2021 Proyecto Final</center></div>

    '''

@app.route('/index')
def index():
  return render_template('index.html')


@app.route('/galeria')
def galeria():
  return render_template('galeria.html')

@app.route('/acercaDe')
def acercaDe():
  return render_template('acercaDe.html')

@app.route('/mapa')
def mapa():
  return render_template('mapa.html')

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Aug/2021 16:03:00] "GET /index HTTP/1.1" 200 -
#  * Running on http://89607da3d5a0.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [16/Aug/2021 16:03:02] "GET /static/photos/1.png HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Aug/2021 16:03:02] "GET /static/photos/2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Aug/2021 16:03:02] "GET /static/photos/6.png HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Aug/2021 16:03:02] "GET /static/photos/vinculate1.png HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Aug/2021 16:03:02] "GET /static/photos/upla1.png HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Aug/2021 16:03:02] "GET /static/photos/12.png HTTP/1.1" 304 -
# ...
